# %% [markdown]
# # Modelling road network of Indian cities

# %%
pip install networkx
# Out:
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (3.3)
#
# [notice] A new release of pip is available: 23.1.2 -> 24.2
# [notice] To update, run: pip3.10 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import networkx as nx
import matplotlib.pyplot as plt
import random

# %%
G = nx.Graph()  # creates an undirected graph

#G = nx.DiGraph()  # Creates a directed graph

city_set = ['Delhi', 'Banglore', 'Hyderabad', 'Ahmedabad', 'Chennai', 'Kolkata', 'Surat', 'Pune', 'Jaipur']

# %%
for each in city_set:
    G.add_node(each)
    
nx.draw(G,)
plt.show()

# %%
costs=[]
value = 100

while (value<= 2000):
    costs.append(value)
    value += 100
    
print(costs)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000]

# %%
# Adding 16 edges to this network 

while(G.number_of_edges()<16):
    c1 = random.choice(list(G.nodes()))
    c2 = random.choice(list(G.nodes()))
    if c1 != c2 and G.has_edge(c1,c2)==0:
        w=random.choice(costs)
        G.add_edge(c1,c2,weight=w)
        
Pos = nx.spectral_layout(G)
nx.draw(G, with_labels=True, pos=Pos)
plt.show()

# %%
# Adding 16 edges to this network 

while(G.number_of_edges()<16):
    c1 = random.choice(list(G.nodes()))
    c2 = random.choice(list(G.nodes()))
    if c1 != c2 and G.has_edge(c1,c2)==0:
        w=random.choice(costs)
        G.add_edge(c1,c2,weight=w)
        
Pos = nx.circular_layout(G)
nx.draw(G, with_labels=True, pos=Pos)
nx.draw_networkx_edge_labels(G, Pos)
plt.show()

# %%
print(nx.is_connected(G))
# Out:
# True

# %%
G = nx.Graph()  # creates an undirected graph

city_set = ['Delhi', 'Banglore', 'Hyderabad', 'Ahmedabad', 'Chennai', 'Kolkata', 'Surat', 'Pune', 'Jaipur'] 

for each in city_set:
    G.add_node(each)
    
costs=[]
value = 100

while (value<= 2000):
    costs.append(value)
    value += 100
    
print(costs)

while(G.number_of_edges()<5):
    c1 = random.choice(list(G.nodes()))
    c2 = random.choice(list(G.nodes()))
    if c1 != c2 and G.has_edge(c1,c2)==0:
        w=random.choice(costs)
        G.add_edge(c1,c2,weight=w)
        
Pos = nx.circular_layout(G)
nx.draw(G, with_labels=True, pos=Pos)
#nx.draw_networkx_edge_labels(G, Pos)
plt.show()

print(nx.is_connected(G))
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000]
# False

# %%
for u in G.nodes():
    for v in G.nodes():
        print(u,v,nx.has_path(G, u,v))
# Out:
# Delhi Delhi True
# Delhi Banglore False
# Delhi Hyderabad True
# Delhi Ahmedabad True
# Delhi Chennai True
# Delhi Kolkata False
# Delhi Surat False
# Delhi Pune True
# Delhi Jaipur True
# Banglore Delhi False
# Banglore Banglore True
# Banglore Hyderabad False
# Banglore Ahmedabad False
# Banglore Chennai False
# Banglore Kolkata False
# Banglore Surat False
# Banglore Pune False
# Banglore Jaipur False
# Hyderabad Delhi True
# Hyderabad Banglore False
# Hyderabad Hyderabad True
# Hyderabad Ahmedabad True
# Hyderabad Chennai True
# Hyderabad Kolkata False
# Hyderabad Surat False
# Hyderabad Pune True
# Hyderabad Jaipur True
# Ahmedabad Delhi True
# Ahmedabad Banglore False
# Ahmedabad Hyderabad True
# Ahmedabad Ahmedabad True
# Ahmedabad Chennai True
# Ahmedabad Kolkata False
# Ahmedabad Surat False
# Ahmedabad Pune True
# Ahmedabad Jaipur True
# Chennai Delhi True
# Chennai Banglore False
# Chennai Hyderabad True
# Chennai Ahmedabad True
# Chennai Chennai True
# Chennai Kolkata False
# Chennai Surat False
# Chennai Pune True
# Chennai Jaipur True
# Kolkata Delhi False
# Kolkata Banglore False
# Kolkata Hyderabad False
# Kolkata Ahmedabad False
# Kolkata Chennai False
# Kolkata Kolkata True
# Kolkata Surat False
# Kolkata Pune False
# Kolkata Jaipur False
# Surat Delhi False
# Surat Banglore False
# Surat Hyderabad False
# Surat Ahmedabad False
# Surat Chennai False
# Surat Kolkata False
# Surat Surat True
# Surat Pune False
# Surat Jaipur False
# Pune Delhi True
# Pune Banglore False
# Pune Hyderabad True
# Pune Ahmedabad True
# Pune Chennai True
# Pune Kolkata False
# Pune Surat False
# Pune Pune True
# Pune Jaipur True
# Jaipur Delhi True
# Jaipur Banglore False
# Jaipur Hyderabad True
# Jaipur Ahmedabad True
# Jaipur Chennai True
# Jaipur Kolkata False
# Jaipur Surat False
# Jaipur Pune True
# Jaipur Jaipur True

# %%
def create_network(City_set, Costs,num_edges):
     G = nx.Graph()
     for each in City_set:
          G.add_node(each)
    
     while(G.number_of_edges()<num_edges):
          c1 = random.choice(list(G.nodes()))
          c2 = random.choice(list(G.nodes()))
          if c1 != c2 and G.has_edge(c1,c2)==0:
               w=random.choice(Costs)
               G.add_edge(c1,c2,weight=w)
               
     return G

# %%
G = create_network(City_set=city_set, Costs=costs, num_edges=10)

# %%
Pos = nx.circular_layout(G)
nx.draw(G, pos= Pos, with_labels = True)
plt.show()

# %%
print(nx.dijkstra_path(G, 'Hyderabad','Delhi'))
# Out:
# ['Hyderabad', 'Delhi']

# %%
print(nx.dijkstra_path_length(G, 'Hyderabad','Delhi'))
# Out:
# 1500
